# %%
# Mackenzie Brown
# Practicum 1 
# 9/11/2026

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits

# %%
# make array 300x200
x = np.arange([0.0,300.0],[0.0,200.0])
x.shape


# x = fits.getdata('filename')
# plt.imshow(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 # make array 300x200
# ----> 2 x = np.arange([0.0,300.0],[0.0,200.0])
#       3 x.shape
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'
