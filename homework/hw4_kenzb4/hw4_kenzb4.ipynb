# %%
#Mackenzie Brown
#Homework 4 
#9/16/2026

# %%
#imports
import numpy as np
import matplotlib.pyplot as plt

# %%
print("Problem 2")

#2a draw random sample of N from gauss dist with given N, sigma, and mu
N = 10000 # number of observations
sigma = 13 # standard deviation
mu = 55 # mean
s = np.random.normal(mu, sigma, N) #draws samples from normaa gaussian distribution
# Out:
# Problem 2

# %%
#2b plot histogram of sample (bins 0-100), width 1, save png

plt.hist(s, bins = range(0,101)) #plot of given N, mu, and sigma values
# sets bin numbers 0-100 width of 1
plt.title("Gaussian Distribution Histogram")
plt.ylabel("N(x)")
plt.xlabel("x")
plt.savefig('hw4_kenzb4_graph1.png')

# %%
#2c use gaussian function to overplot, gauss distr, same mu & sigma
#approx integration between bin boundaries (0,100) by...
# evaluation at center of each bin (bin[1,2] eval x=1.5)
#multiply function by tot number of draws N to get expected
#num of draws per bin (for larger sample)

plt.hist(s, bins = range(0,101)) #regular plot 



#its all a GUESS DOWN HERE, COME AND CORRECT
#est = plt.plot(bins = range(0,101))

#prob_density = 1 / (sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins-mu)**2 / (2 * mu**2))
#print(prob_density)

#from lecture to refrence (below)
#dm = plt.plot(bins=range(0,101), np.max(count)* 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
        # linewidth=2, color='r')

# plots bin, highest value bin number times 1/sigma times sqrt of 2pi times e^-(bin - deviation)squared /
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 11
#       7 plt.hist(s, bins = range(0,101)) #regular plot
#       9 #est = plt.plot(bins = range(0,101))
# ---> 11 prob_density = 1 / (sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins-mu)**2 / (2 * mu**2))
#      12 print(prob_density)
#
# NameError: name 'bins' is not defined
