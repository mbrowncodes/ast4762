# %%
#CHAPTER 3, FUNCTIONS

# %%
# whats inside paratheses is a arugment
# a function takes an argument and returns a result

# %%
import math
# module object is math, 
decibels = 10* math.log10(5)

radians = 0.7
height = math.sin(radians)

# %%
# first line of function definition - header, the rest - body
# header end with :, body indented 
# once function defined, you can call function inside another 
# when defining function, need to known order statements run in, top to bottom
# statements inside arent ran until funct called
# inside funct (), arugment assigned to variable (parameter)
# variable inside function = local
# make program smaller, eliminate repetitive code

# %%
#exercise 3.14

# %%
# write funt right_justify taking in string name s and print the string with leading
#spaces so last letter of string is in column 70 of display

def right_justify (s):
    """
    input: s - string
    output: prints string, leading spaces so last letter in column 70
    """

    print(len(s))
s = "monty"
print(s)
print(len(s))

position = 70 - len(s)
print(position)
# Out:
# monty
# 5
# 65
