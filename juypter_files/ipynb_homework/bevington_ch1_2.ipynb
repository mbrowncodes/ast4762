# %%
# Bevington Chapter Notes (1&2)
# Mackenzie Brown
# 9/10/2026

# %%
# Chapter 1 Uncertainties in Measurements

# %%
# all experiments encounter error and uncertainties 
# must be reduced by imporving techniques and repeat measurements 
# estimate errors --> establish validity in results

# %%
# illegitimate errors:
  # originate from mistsake/blunder in measure or computing
  # can be corrected by carefully repeating operations

# accuracy vs precision:
  # a: how close result is to true value
  # p: reproducibility of result
  # uncertainity/error --> refer to precision of result found
  # absolute precision= mag of uncertainity in result in same unit of result
  # relative precision= uncertainty in terms of fraction of value of result

# systematic errors
  # accuracy depend on how well we control systematic errors 
  # these are things that make the results different from true values
  # not easy to see, not easily studied (faulty calibration of equip)
  # plan experiment : understand & reduce source of systematic errors


# random errors
  # precision depend on how well we overcome random errors
  # flux in observation giving different results each time
  # accuracy imply = precision (depend on random error)
  # if from instrument --> reduce by using more precisie measuring instruments 
  # if from statistical fluctuations--> take more measurements

# %%
# Significant Figures and Roundoff
  # precision of result --> implied by number sig fig
  # leftmost digit: most signifiicant digit
  # no decimal pt: rightmost nonzero digit least significant
  # decimal pt: rightmost digit least significant (even if 0)
  # all digit between least and most sig dig are counted as sig dig
  # write in scientific notation if all digits are sig (ie 1010 looks like 3 sig fig)
  # experimental result: # sig fig = 1 extra than dictated by experimental precision
  # --> reason: avoid errors caused by rounding errors (in calculations)
  # if it equals 1/2 aka 0.5 increment least sig dig only iff odd
  # only round final values

# %%
# Uncertainties
  # 2 groups: 
  # 1: from flux in measurements
  # 2: associated with theoretical description of our result 
  # error --> deviation of result from true value
  # usually cant know true value, can only estimate errors inherent in experiment
  # repeat experiment, results differ --> discrepancy between 2 results
  # ie: compare diff measurements of standard physical constant & compare results
  # ... refer to difference as discrepancies not error/uncertainties
  # MUST develop consistent method for determine & quote estimated error

# Minimize Uncertainties & Best Resultls
  # want max amount of useful info from data (w/out needing to repeat)
  # extract best estimate of theoretical parameters and random errors from data
  # understand effect of errors on our results

# Parent and Sample Distributions
  # measure x1 of quantity x, expect observation to approx quantity
  # dont expect data point to be exactly == to quantity
  # when taking more measurements --> see pattern from discrepancy in data
  # some too high some too low --> distributed around correct value !! look for
  # parent distribution: hypothesize the existence of distribution that determine
  #... probability of getting anybody particualr observation in 1 measruement
  # measurements we made are samples of parent dis 
  # infinite measurement, sample --> parent 
  # sum all measurements, parent is lim N--> infinity of (experimental paramter)

# Mean, Median, Mode
  # mean: sum of N determinations xi of quantity x divided by number of determinations
  # mean of parent funct (mew) def = lim N-->infi(1/N * sum xi)
  # median: parent half less then median and half greater (probability %50, big or small)
  # ^^^^ not often used 
  # mode: most porbable value (mew max) parent distribution has greatest value
  # most likely to be observed
  # defined with respect to mean for computation!
  # variance and standard deviation characterize uncertaintites
  #

# %%
# Mean and Standard Deviation of distribution of Distributions 
  # probability density p(x) 
  # mean of mew is expectation value <x>
  # variance is expecation value of square of deviation from x and mew
  # 
  #
  #

# %%
# Chapter 2 Probability Distributions

# %%
#31 - 48 (pdf not pages)

# 3 main distributions
# binomial, poisson, gaussian (most important)
# g: statistical analysis --> describe distribution of random observation
# p: counting experiments (data rep # items/events in time interval) radio decay
# b: result = small number of possible finanle states (head vs tail)
# p and g are limiting cases of b

# %%
# Binomial Distribution
# probabilty P(x; n) function of n(number) varys as functional of x (integer for
#physical experiments)
# perfutations Pm(n,x) = n!/(n-x)!
# number of combos C(n, x) = Pm(n,x)/x! = n!/x!(n-x)!  = (n)
#                                                        (x)
# probability is product of number of combos contributing to set of observs
# multipled by probability for each conbo to happen (1/2)^n
# binomial distribution with Pb(x;n, p) = n!/(x!(n-x)!)  * p**x *(1-p)**n-x
# normalized to sum of 1 (something has to happen so =1)
# mean of binom dist --> do experiment, n tiems, observe x successes
# w/ enough repeated experiment, avg x approach mean value mew
# variance of bionm dist: p=q=1/2 (symmetric about mean) p!=q --> asymetric, variance smaller

# %%
# Poisson Distribution
# approx of bionm dist (special case), avg # sucesses much smaller than possible number
# ie mew <<< n, bc p<<1
# neither n(possible events) or p (probability) is known
# can know avg number of events mew, expectd in time interval (avg x estimate)
# limiting case p<<1
    # behavior as n --> infinity (??) while mew (mean) = np is constant 
    # find binom dist Pb asymptotically approach poisson dist, as p-->0
    # Pp !=0 for x=0, becomes neg, but cant have neg time intervals

# discrete distribution, defined only at integral values of x

# %%
# Gaussian/Normal Error Distribution
# n (number of possible diff observs) become infinitaly large 
# np>> 1
# continous function (g prob density eq), define interval which value of x (observed) will fall
#

# %%
# Comparing the two
# P: only defined at 0 and positive integral values of x
# G: defined at all value of x

# %%
# Lorentizian Distribution
# appropriate distribution for describe data corresponding to resonant behavior
# ie variation with energy of cross section of nuclear reaction
# symmetric about its mean, does not dimish to 0 as rapdily as G 
# continous function, integral unbounded, but does not converge for large deviations
# width characterized by full with at half maximum (half width)

# %%
# SUMMARY 
# B distribution: probabilty of observing x successes out of n tries when prob for success = p
# P distribution: large n, constant mew, describe small sample ,large population
# G distribution: large n, finite p, smooth symmetric distribution 
# L distribution: resonant behavior
